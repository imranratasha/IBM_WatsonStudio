# %% [markdown]
#  # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Imran Ratasha <b>

# %% [markdown]
# I want to become a machine learning expert

# %% [markdown]
# _I am interested in data science because it is such a huge opportunity for the future. I want to become a professional data scientist_

# %% [markdown]
# ### In cell 5, my code should be a "Hello World' output

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# * 1
# * 2
#
# 1. Hello
# 2. Hi
#
# [This is a google link](https://www.google.com/)
